# %%
import numpy as np

# %%
rolls = np.random.randint(1, 7, size=10000)

# %%
expected_value = np.mean(rolls)

# %%
variance = np.var(rolls)

# %%
print("=" * 50) 
print("DICE SIMULATION RESULTS")
print("=" * 50)
print(f"Expected Value (Average): {expected_value:.4f}")
# Out:
# ==================================================
# DICE SIMULATION RESULTS
# ==================================================
# Expected Value (Average): 3.5152

# %%
for number in range(1, 7):  
    count = np.sum(rolls == number) 
    probability = count / 10000    
    print(f"Probability of {number}: {probability:.2%}")
# Out:
# Probability of 1: 16.16%
# Probability of 2: 16.72%
# Probability of 3: 17.20%
# Probability of 4: 16.18%
# Probability of 5: 16.84%
# Probability of 6: 16.90%
