# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Anusha"
print(name)
# Out:
# Anusha

# %%
age = 22
print(age)
# Out:
# 22

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
a = 50
b = 15
print(a - b)
# Out:
# 35

# %%
a = 5
b = 4
print(a * b)
# Out:
# 20

# %%
a = 20
b = 5
print(a / b)
# Out:
# 4.0

# %%
x = 3.14
print(type(x))
# Out:
# <class 'float'>

# %%
text = "Python"
print(text)
# Out:
# Python

# %%
text = "python"
print(text.upper())
# Out:
# PYTHON

# %%
word = "Notebook"
print(len(word))
# Out:
# 8

# %%
text = "Python"
print(text[::-1])
# Out:
# nohtyP

# %%
first = "Hello"
second = "World"
print(first + " " + second)
# Out:
# Hello World

# %%
fruits = ["apple", "banana", "mango"]
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'orange']

# %%
fruits = ["apple", "banana", "mango"]
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'mango']

# %%
numbers = [10, 20, 30, 40]
print(numbers[2])
# Out:
# 30

# %%
colors = ("red", "green", "blue")
print(colors)
# Out:
# ('red', 'green', 'blue')

# %%
colors = ("red", "green", "blue")
print(colors[1])
# Out:
# green

# %%
student = {
    "name": "Anusha",
    "age": 22
}
print(student)
# Out:
# {'name': 'Anusha', 'age': 22}

# %%
numbers = {1, 2, 3}
numbers.add(4)
print(numbers)
# Out:
# {1, 2, 3, 4}
